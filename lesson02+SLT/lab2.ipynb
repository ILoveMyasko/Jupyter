# %% [markdown]
# ### 1. Metadata
# ####Description
# This dataset provides an overview of some factors that might affect student's performance in exams.
#
# ####Column Descriptions
# - **Gender**:	Gender of the student (Male, Female).
# - **Race/ethnicity**    Race of ethnicity of a student (groups from A to E).
# - **Parental_education**:	Level of parental education (school, some colledge, bachelor degree, etc.).
# - **Lunch**:	Standard of free/reduced lunch.
# - **Test preparation course**:	Has a student completed a preparation course (Yes, No).
# - **Math score**: Final score for math exam (0-100).
# - **Reading score**:	Final score for reading exam (0-100).
# - **Writing score**:	Final score for writing exam (0-100).

# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataset = pd.read_csv("StudentsPerformance.csv", skipinitialspace=True)
dataset.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# print important information about dataset
print("#Total of samples = ", dataset.shape[0])
print("#Features = ", dataset.shape[1])
# Out:
# #Total of samples =  1000
# #Features =  8

# %%
# samples with missing values
dataset[dataset.isna().any(axis=1)].head()
print("#Samples with missing values = ", len(dataset[dataset.isna().any(axis=1)]))
# Out:
# #Samples with missing values =  0

# %% [markdown]
# No missing data.

# %%
# plot missing data
sbn.displot(
    data = dataset.isna().melt(value_name="missing"),
    y = "variable",
    hue = "missing",
    multiple = "fill",
    aspect = 1.5
)

plt.show()

# %%
# list of numerical variables
numerical_cols = ['math score', 'writing score','reading score']

# %%
# function to plot distribution for 1 numerical column
def hist_frequencies(data, column, bins):
    sbn.histplot(data[column], color = "blue", bins = bins)
    plt.xlabel(column)
    plt.ylabel("Frequencies")
    plt.title("Histogram distribution for " + column)
    plt.show()

# %%
numerical_cols
# Out:
# ['math score', 'writing score', 'reading score']

# %%
hist_frequencies(dataset,'math score', 10)

# %%
hist_frequencies(dataset,"writing score", 10)

# %%
hist_frequencies(dataset,"reading score", 10)

# %% [markdown]
# The Kernel Density Estimator provides a smooth curve that represents the distribution of data points based on estimating the probability density function of a random variable:
# $$ \hat{f}(x; h) = \frac{1}{n} \sum_{i=1}^{n} K_h(x - X_i) $$
# Where:
# * n: total number of data points
# * $X_i$: observed data points
# * $K_h$: kernel function scaled by the bandwidth h
# $$ K_h(z) = \frac{1}{h} K\left(\frac{z}{h}\right) $$
# * $K$: Gaussian Kernel
# $$ K(x) = \frac{1}{\sqrt{2\pi}} e^{-\frac{x^2}{2}} $$

# %%
# function to plot distribution for 1 numerical column
def hist_density(data, column, bins):
    sbn.histplot(data[column], color = "blue", bins = bins, kde = False, stat = "density", alpha = 0.5)
    sbn.kdeplot(data[column], color = "red", linewidth = 2)
    plt.xlabel(column)
    plt.ylabel("Density")
    plt.title("Histogram and KDE for " + column)
    plt.show()

# %%
hist_density(dataset, "math score", 10)

# %%
hist_density(dataset, "writing score", 10)

# %%
hist_density(dataset, "reading score", 10)

# %% [markdown]
# According to these histograms all scores have normal distibution.
#
# Math score: most of the students have 60-70 points for this exam, with very few having more than 90 and less than 50.
# Writing score: most of the students have 70-80 points, but still very few have a score more than 90 or less than 50.
# Reading score: clearly the average score is 70, very few students have 50 or less. But a lot of them actually have 90+.

# %%
# function to make boxplot
def statistics_nvar(data, numerical_cols):
    # calculate the nrows and ncols for plots
    ncol_plots = 2
    nrow_plots = (len(numerical_cols) + ncol_plots - 1) // ncol_plots
    # create the subplots for specific row and column
    fig, axs = plt.subplots(nrow_plots, ncol_plots, figsize = (16, 4 * nrow_plots))
    axs = axs.flatten()
    # create boxplots for each numerical column
    for i, col in enumerate(numerical_cols):
        sbn.boxplot(data[col], ax = axs[i])
        axs[i].set_title("Box plot for " + col)
    plt.tight_layout()
    plt.show()

# %%
# boxplot for each numerical column
statistics_nvar(dataset, numerical_cols)

# %% [markdown]
# According to these boxes we can say that a student on average gets 65 points for math exam, 70 for writing and 70 for reading.

# %%
# statistical information about numerical variables
dataset[numerical_cols].describe()
# Out:
#        math score  writing score  reading score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      68.054000      69.169000
# std      15.16308      15.195657      14.600192
# min       0.00000      10.000000      17.000000
# 25%      57.00000      57.750000      59.000000
# 50%      66.00000      69.000000      70.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# Correlation Analysis

# %% [markdown]
# The correlation between 2 variables quantify the linear relationship between the variables X and Y:
# $$ r = \frac{\text{Cov}(X, Y)}{\sigma_X \sigma_Y} $$
# Where:
#
# $r$: pearson correlation coefficient
# $Cov(x, y)$: covariance between variables X and Y. It measures how much the two variables change together.
# $\sigma_X, \sigma_Y$: standard deviations for variables X and Y.
#
# Formula of Covariance:
# $$ \text{Cov}(X, Y) = \frac{1}{n-1} \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y}) $$
# Formula for standard deviation for X:
# $$ \sigma_X = \sqrt{\frac{1}{n-1} \sum_{i=1}^{n} (X_i - \bar{X})^2} $$
# Formula for standard deviation for Y:
# $$ \sigma_Y = \sqrt{\frac{1}{n-1} \sum_{i=1}^{n} (Y_i - \bar{Y})^2} $$

# %%
# function to plot correlation between numerical variables
def plot_correlation(data, cols):
    corr = data[cols].corr()
    plt.matshow(corr, cmap = "coolwarm")
    plt.xticks(range(len(cols)), cols, rotation = 90)
    plt.yticks(range(len(cols)), cols)

    # add the correlation values in each cell
    for (i, j), val in np.ndenumerate(corr):
        plt.text(j, i, f"{val:.1f}", ha='center', va='center', color='black')
    plt.title("Correlation Analysis")
    plt.colorbar()
    plt.show()

# %%
plot_correlation(dataset, numerical_cols)

# %% [markdown]
# We don't have much numerical columns so its really hard to get anything from it, but we can definitely see high level of correlation between reading score and writing score, which is obvious why.

# %%
# function to plot gaussian kernel
def plot_gaussian_kernel(mean=0, std_dev=1, num_points=1000):
    # Generate x values
    x = np.linspace(mean - 4 * std_dev, mean + 4 * std_dev, num_points)

    # Calculate the Gaussian kernel values
    gaussian_kernel = (1 / (np.sqrt(2 * np.pi) * std_dev)) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(x, gaussian_kernel, color='blue', label=f'Gaussian Kernel\nMean = {mean}, Std Dev = {std_dev}')
    plt.title('Gaussian Kernel')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.axvline(mean, color='red', linestyle='--', label='Mean')
    plt.legend()
    plt.grid()
    plt.show()

# %%
# standard gaussian kernel
plot_gaussian_kernel(mean=0, std_dev=1)

# %%
from scipy.stats import norm

# Calculate the percentile for a specific Z-score
def call_percentile(z):
    percentile = float(round(norm.cdf(z) * 100, 3))
    return percentile

# %%
call_percentile(z = -2)
# Out:
# 2.275

# %%
from scipy import stats

# Function for outliers detection based on percentiles
def outliers_detection(dataset, col, lower_percentile=2.275, upper_percentile=97.725):
    # Calculate the percentiles
    lower_bound = dataset[col].quantile(lower_percentile / 100)
    upper_bound = dataset[col].quantile(upper_percentile / 100)

    # Filter out the outliers
    outliers = dataset[(dataset[col] < lower_bound) | (dataset[col] > upper_bound)]

    return outliers

# %%
outliers_detection(dataset, "math score").head()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 17  female        group B            some high school  free/reduced
# 34    male        group E                some college      standard
# 55  female        group C                 high school  free/reduced
# 59  female        group C            some high school  free/reduced
# 76    male        group E            some high school      standard
#
#    test preparation course  math score  reading score  writing score
# 17                    none          18             32             28
# 34                    none          97             87             82
# 55                    none          33             41             43
# 59                    none           0             17             10
# 76                    none          30             26             22

# %%
# cycle to check the number of outliers in each numerical column
for col in numerical_cols:
    print("\n*** Outliers detection in " + col + " ***")
    lst_outliers = outliers_detection(dataset, col)
    print(f"#samples outlier to distribution = {len(lst_outliers)}")
    print(f"%outliers = {round(100* len(lst_outliers)/len(dataset), 2)} %")
# Out:
# *** Outliers detection in math score ***
# #samples outlier to distribution = 44
# %outliers = 4.4 %
#
# *** Outliers detection in writing score ***
# #samples outlier to distribution = 44
# %outliers = 4.4 %
#
# *** Outliers detection in reading score ***
# #samples outlier to distribution = 40
# %outliers = 4.0 %

# %%
# list of categorical variables
categorical_vars = list(set(dataset.columns) - set(numerical_cols))
categorical_vars
# Out:
# ['gender',
#  'test preparation course',
#  'race/ethnicity',
#  'lunch',
#  'parental level of education']

# %%
# cycle to calculate number of instances in each categorical column
for col in categorical_vars:
    print("\n***** " + col + " ******")
    print(dataset[col].value_counts())
# Out:
# ***** gender ******
# gender
# female    518
# male      482
# Name: count, dtype: int64
#
# ***** test preparation course ******
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64
#
# ***** race/ethnicity ******
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64
#
# ***** lunch ******
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64
#
# ***** parental level of education ******
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %% [markdown]
# Bar chart - Analysis of absolute frequencies

# %%
# function to plot bar chart for absolute frequencies in 1 categorical column
def plot_barchart(dataset, col):
    results = dataset[col].value_counts()
    sbn.barplot(x = results.values.tolist(), y = results.index.tolist(), orient = "y")
    plt.title("Statistical analysis by " + col)
    plt.show()

# %%
# cycle to plot bar chart for each categorical column
for col in categorical_vars:
    plot_barchart(dataset, col)

# %% [markdown]
# According to these bar charts, an average student have not completed a preparation course, had standard lunch, represents ethnicity group C and his parents studied or finished a colledge.

# %% [markdown]
# Pie Chart - Analysis of relative frequencies

# %%
# function to plot pie chart for relative frequencies in 1 categorical column
def plot_piechart(dataset, col):
    # count the #samples for each categogy
    results = dataset[col].value_counts()
    # calculate the relative frequencies
    total_samples = results.sum()
    rel_freq = results/total_samples
    sbn.set_style("whitegrid")
    plt.figure(figsize=(6,6))
    plt.pie(rel_freq.values.tolist(), labels = rel_freq.index.tolist(), autopct='%1.1f%%')
    plt.title("Relative frequency analysis by " + col)
    plt.show()

# %%
# cycle to plot pie chart for each categorical column
for col in categorical_vars:
    plot_piechart(dataset, col)

# %% [markdown]
# Pie charts represents the same data in a different form.

# %% [markdown]
# Statistical Analysis for subgroups

# %%
# create groups organized by gender and parental level of education
group_gender_parental_loe = dataset.groupby(["gender", "parental level of education"]).size().reset_index(name = "samples")
print(group_gender_parental_loe)
# Out:
#     gender parental level of education  samples
# 0   female          associate's degree      116
# 1   female           bachelor's degree       63
# 2   female                 high school       94
# 3   female             master's degree       36
# 4   female                some college      118
# 5   female            some high school       91
# 6     male          associate's degree      106
# 7     male           bachelor's degree       55
# 8     male                 high school      102
# 9     male             master's degree       23
# 10    male                some college      108
# 11    male            some high school       88

# %%
# function to plot absolute frequencies for groups
def plot_absfreq_groups(group, g1, g2):
    sbn.barplot(data = group, x = g1, y = "samples", hue = g2, palette = "pastel")
    plt.xlabel('gender')
    plt.ylabel('parental level of education')
    plt.title('Bar Chart of gender by parental level of education')
    plt.tight_layout()
    plt.show()

# %%
plot_absfreq_groups(group_gender_parental_loe, "gender", "parental level of education")

# %% [markdown]
# This diagramm show that most of the students parents studied in colledge or got associate's degree

# %%
# function to plot relative frequencies for groups
def plot_relfreq_groups(group, g1, g2):
    labels = group[g1] + ': ' + group[g2]
    sizes = group["samples"]
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
    plt.axis('equal')
    plt.title('Pie Chart of Relative Frequencies by Gender and parental level of education')
    plt.show()

# %%
plot_relfreq_groups(group_gender_parental_loe, "gender", "parental level of education")
